# %%
import mysql.connector as connection
import csv

with open('carbon_nanotubes.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=';')
    line_count = 0
    data = []
    for row in csv_reader:
        if line_count == 0:
            line_count += 1
        else:
            data.append(tuple(row))
            line_count += 1

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
cur = mydb.cursor()
#cur.execute("Create database UCI")
cur.execute("CREATE TABLE IF NOT EXISTS UCI2.carbon_nanotubes(Chiral_indice_n INT(5),Chiral_indice_m INT(5), Initial_atomic_coordinate_u nvarchar(15), Initial_atomic_coordinate_v nvarchar(15),Initial_atomic_coordinate_w nvarchar(15)," \
            " Calculated_atomic_coordinates_u nvarchar(15), Calculated_atomic_coordinates_v nvarchar(15), Calculated_atomic_coordinates_w nvarchar(15))")

# %%
mySql_insert_query = """INSERT INTO UCI2.carbon_nanotubes VALUES (%s, %s, %s, %s, %s, %s, %s, %s) """

records_to_insert = data

cur = mydb.cursor()
cur.executemany(mySql_insert_query, records_to_insert)
mydb.commit()
print(cur.rowcount, "Record inserted successfully into UCI2.carbon_nanotubes table")
# Out:
# 10721 Record inserted successfully into UCI2.carbon_nanotubes table

# %% [markdown]
# # The SQL SELECT QUERY

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_select_query = """select Chiral_indice_n, Chiral_indice_m from UCI2.carbon_nanotubes"""
cur = mydb.cursor()
cur.execute(mySql_select_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mySql_select_query = """select * from UCI2.carbon_nanotubes """
cur = mydb.cursor()
cur.executemany(mySql_select_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL SELECT DISTINCT

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_select_query = """select distinct Chiral_indice_n from UCI2.carbon_nanotubes """
cur = mydb.cursor()
cur.execute(mySql_select_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL WHERE CLAUSE

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_select_query = """select Calculated_atomic_coordinates_w from UCI2.carbon_nanotubes where Calculated_atomic_coordinates_u='0,721039' """
cur = mydb.cursor()
cur.execute(mySql_select_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_select_query = """select Calculated_atomic_coordinates_w from UCI2.carbon_nanotubes where Chiral_indice_n=2 """
cur = mydb.cursor()
cur.execute(mySql_select_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_select_query = """select Calculated_atomic_coordinates_w from UCI2.carbon_nanotubes where Chiral_indice_n between 2 and 7 """
cur = mydb.cursor()
cur.execute(mySql_select_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL WHERE CLAUSE WITH AND, OR & NOT

# %% [markdown]
# # A WHERE clause with AND:

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_select_query = """select Calculated_atomic_coordinates_w from UCI2.carbon_nanotubes where Chiral_indice_n=2 and Chiral_indice_m=1 """
cur = mydb.cursor()
cur.execute(mySql_select_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # A WHERE clause with OR:

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_select_query = """update UCI2.carbon_nanotubes set Initial_atomic_coordinate_u='0,679005' where Chiral_indice_m=1 limit 20; """
cur = mydb.cursor()
cur.execute(mySql_select_query)
mydb.commit()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_select_query = """select Chiral_indice_n from UCI2.carbon_nanotubes where not Chiral_indice_m=1 limit 20; """
cur = mydb.cursor()
cur.execute(mySql_select_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL ORDER BY

# %% [markdown]
# # Order By in Descending order

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_order_query = """select Chiral_indice_n, Chiral_indice_m from UCI2.carbon_nanotubes order by Chiral_indice_n desc;"""
cur = mydb.cursor()
cur.execute(mySql_order_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Order By in Ascending order

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_order_query = """select Chiral_indice_n, Chiral_indice_m from UCI2.carbon_nanotubes order by Chiral_indice_n asc;"""
cur = mydb.cursor()
cur.execute(mySql_order_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL MIN() AND MAX() FUNCTION

# %% [markdown]
# # MIN() Syntax

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_min_query = """select min(Chiral_indice_n) from UCI2.carbon_nanotubes;"""
cur = mydb.cursor()
cur.execute(mySql_min_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # MAX() Syntax

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_max_query = """select max(Chiral_indice_n) from UCI2.carbon_nanotubes;"""
cur = mydb.cursor()
cur.execute(mySql_max_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL COUNT(), AVG() AND SUM() FUNCTION

# %% [markdown]
# # COUNT() Syntax

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_count_query = """select count(Chiral_indice_n=12) from UCI2.carbon_nanotubes; """
cur = mydb.cursor()
cur.execute(mySql_count_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # AVG() Syntax

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_avg_query = """select avg(Chiral_indice_n) from UCI2.carbon_nanotubes; """
cur = mydb.cursor()
cur.execute(mySql_avg_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # SUM() Syntax

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_sum_query = """select sum(Chiral_indice_n) from UCI2.carbon_nanotubes; """
cur = mydb.cursor()
cur.execute(mySql_sum_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL LIKE-OPERATOR

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_like_query = """select * from UCI2.carbon_nanotubes where Initial_atomic_coordinate_u like '0,63%'; """
cur = mydb.cursor()
cur.execute(mySql_like_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_like_query = """select * from UCI2.carbon_nanotubes where Initial_atomic_coordinate_u like '%257'; """
cur = mydb.cursor()
cur.execute(mySql_like_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_like_query = """select * from UCI2.carbon_nanotubes where Initial_atomic_coordinate_u like '%372%'"""
cur = mydb.cursor()
cur.execute(mySql_like_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_like_query = """select * from UCI2.carbon_nanotubes where Initial_atomic_coordinate_u like '0,6%67';"""
cur = mydb.cursor()
cur.execute(mySql_like_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL IN AND NOT IN OPERATORS

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_like_query = """select * from UCI2.carbon_nanotubes where Initial_atomic_coordinate_u like '0,6__%';"""
cur = mydb.cursor()
cur.execute(mySql_like_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_in_query = """select * from UCI2.carbon_nanotubes where Chiral_indice_n in(1,5,9) ;"""
cur = mydb.cursor()
cur.execute(mySql_in_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_in_query = """select * from UCI2.carbon_nanotubes where Chiral_indice_n not in(1,5,9) ;"""
cur = mydb.cursor()
cur.execute(mySql_in_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL BETWEEN OPERATOR

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_between_query = """select * from UCI2.carbon_nanotubes where Chiral_indice_n between 2 and 5;"""
cur = mydb.cursor()
cur.execute(mySql_between_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_between_query = """select * from UCI2.carbon_nanotubes where Chiral_indice_n not between 2 and 5;"""
cur = mydb.cursor()
cur.execute(mySql_between_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL ALIAS

# %% [markdown]
# # Alias Column Syntax

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_alias_query = """select Chiral_indice_n as cin from UCI2.carbon_nanotubes;"""
cur = mydb.cursor()
cur.execute(mySql_alias_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Alias Table Syntax

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_alias_query = """select u.Chiral_indice_n from UCI2.carbon_nanotubes as u;"""
cur = mydb.cursor()
cur.execute(mySql_alias_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL GROUP BY STATEMENT

# %% [markdown]
# # Count the number of rows of Chiral_indice_n based different values of Chiral_indice_m

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_group_query = """SELECT count(Chiral_indice_n) FROM UCI2.carbon_nanotubes GROUP BY Chiral_indice_m;"""
cur = mydb.cursor()
cur.execute(mySql_group_query)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The SQL HAVING CLAUSE

# %% [markdown]
# # List number of Chiral_indice_m where number of rows of Chiral_indice_n > 45000

# %%
mydb = connection.connect(host="localhost", user="root", passwd="mysql",use_pure=True)
mySql_having_query = """select * from UCI2.carbon_nanotubes group by Chiral_indice_m having count(Chiral_indice_n) > 45000;"""
cur = mydb.cursor()
cur.execute(mySql_having_query)

# %% [markdown]
# ![image.png](attachment:image.png)
